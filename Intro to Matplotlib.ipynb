# %% [markdown]
# # Intro to Matplotlib

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %% [markdown]
# plt.plot([1,2,3,4])

# %%
y= [21,12,63,84]
x= [1,2,3,4]
plt.plot(x,y)

# %% [markdown]
# # 1st method

# %%
fig = plt.figure() # creates a figure
ax = fig.add_subplot() #adds some axes
plt.show()

# %% [markdown]
# # 2nd method

# %%
fig = plt.figure() # creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y)
plt.show()

# %% [markdown]
# # 3rd method

# %%
fig, ax = plt.subplots()
ax.plot(x,y);

# %% [markdown]
# ## Matplotlib example and get it ready for potting in JP

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 4]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) #creates hight and width 

# 3. Plot the data
ax.plot(x, y)

# 4. Customize plot
ax.set(title="Simple Plot", # title of the pic 
       xlabel="x-axis",    # x=width
       ylabel="y-axis")    # y=hight

# 5. Save and show
fig.savefig("sample_plot.png")
plt.show()

# %% [markdown]
# # Making figures with NUMPY arrays
# We'll make
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# # Plot the data

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2)

# %% [markdown]
# # Scatter plot

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %% [markdown]
# # Make a plot from dict

# %%
car_price = {"M.Benz" : 10.000,
            "BMW": 20.000,
            "Lanborghini": 90.000}
fig, ax = plt.subplots()
ax.bar(car_price.keys(), car_price.values())
ax.set(title = "Car Prices in 2024",
      ylabel= "Price in $",
      xlabel = "Car brand")
# Out:
# [Text(0.5, 1.0, 'Car Prices in 2024'),
#  Text(0, 0.5, 'Price in $'),
#  Text(0.5, 0, 'Car brand')]

# %%
fig, ax = plt.subplots()
ax.barh(list(car_price.keys()), list(car_price.values()));
ax.set(title = "Car Prices in 2024",
      ylabel= "Price in $",
      xlabel = "Car brand")
# Out:
# [Text(0.5, 1.0, 'Car Prices in 2024'),
#  Text(0, 0.5, 'Price in $'),
#  Text(0.5, 0, 'Car brand')]

# %% [markdown]
# # Histogram plot

# %%
x = np.random.rand(10)
fix, ax = plt.subplots();
ax.hist(x);

# %% [markdown]
# # Two options for subplots

# %%
# First option
fig, ((ax1, ax2), (ax3,ax4)) = plt.subplots(nrows =2,
                                          ncols =2,
                                          figsize=(10,5))
ax1.plot(x, x/2);
ax2.scatter(np.random.rand(10), np.random.rand(10));
ax3.bar(car_price.keys(), car_price.values());
ax4.hist(np.random.rand(100));

# %%
# Second option

fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))

# Plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.rand(10), np.random.rand(10));
ax[1,0].bar(car_price.keys(), car_price.values());
ax[1,1].hist(np.random.rand(100));

# %% [markdown]
# # Let's include some Panda stuff

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
In [3]: np.random.seed(123456)

In [4]: ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

In [5]: ts = ts.cumsum()

In [6]: ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)
car_sales["Sale Date"] = pd.date_range(start="1/1/2020", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   400000 2020-01-01       400000
# 1   Honda    Red          87899      4   500000 2020-01-02       900000
# 2  Toyota   Blue          32549      3   700000 2020-01-03      1600000
# 3     BMW  Black          11179      5  2200000 2020-01-04      3800000
# 4  Nissan  White         213095      4   350000 2020-01-05      4150000
# 5  Toyota  Green          99213      4   450000 2020-01-06      4600000
# 6   Honda   Blue          45698      4   750000 2020-01-07      5350000
# 7   Honda   Blue          54738      4   700000 2020-01-08      6050000
# 8  Toyota  White          60000      4   625000 2020-01-09      6675000
# 9  Nissan  White          31600      4   970000 2020-01-10      7645000

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   400000 2020-01-01       400000
# 1   Honda    Red          87899      4   500000 2020-01-02       900000
# 2  Toyota   Blue          32549      3   700000 2020-01-03      1600000
# 3     BMW  Black          11179      5  2200000 2020-01-04      3800000
# 4  Nissan  White         213095      4   350000 2020-01-05      4150000
# 5  Toyota  Green          99213      4   450000 2020-01-06      4600000
# 6   Honda   Blue          45698      4   750000 2020-01-07      5350000
# 7   Honda   Blue          54738      4   700000 2020-01-08      6050000
# 8  Toyota  White          60000      4   625000 2020-01-09      6675000
# 9  Nissan  White          31600      4   970000 2020-01-10      7645000

# %% [markdown]
# # Plot the total sales

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind = "scatter");

# %%
import pandas as pn
x = np.random.rand(10,4)
new_frame = pn.DataFrame(x, columns=["a","b","c","d",])
new_frame
# Out:
#           a         b         c         d
# 0  0.782124  0.811285  0.493067  0.798854
# 1  0.258588  0.550333  0.277922  0.139915
# 2  0.208449  0.450051  0.707760  0.484560
# 3  0.507504  0.203877  0.598768  0.323564
# 4  0.881448  0.988387  0.512833  0.495326
# 5  0.783813  0.685881  0.293582  0.143242
# 6  0.452377  0.192240  0.709589  0.880214
# 7  0.057323  0.206479  0.504485  0.095000
# 8  0.167471  0.895322  0.865932  0.874867
# 9  0.655697  0.576228  0.675267  0.277310

# %%
new_frame.plot.bar()
# Out:
# <Axes: >

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind=("bar"));

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot.hist(bins=30);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease["age"].plot.hist(bins=30);

# %% [markdown]
# # Another file

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %% [markdown]
# # PYPLOT method

# %%
over_50.plot(kind ="scatter",
            x="age",
            y="chol",
            c="target",
             figsize = (10,6)
            )
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %% [markdown]
# # OO method

# %%
fig, ax = plt.subplots(figsize=(10,7))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax = ax);
ax.set_xlim([45,100]);
